# %% [markdown]
# <a href="https://colab.research.google.com/github/SHARUKA-2005/CrimeSpotMLmodel/blob/main/Pol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from google.colab import files
from sklearn.metrics import accuracy_score, classification_report

# %%
police_dataset = pd.read_csv('/content/tuticorin_crime_dataset.csv')

# %%
police_dataset.head()
# Out:
#       area_name   latitude  longitude  pincode  population  male_population  \
# 0   Rajaji Park  13.130490  80.387909   600017       19127             9820
# 1  Kailasapuram  12.888904  80.378071   600038      262099           129929
# 2      Kayathar  12.946194  80.142256   600088      148307            75580
# 3   Arumuganeri  13.064324  80.371663   600071       86763            43005
# 4    Punnakayal  12.896588  80.144548   600039       28431            14165
#
#    female_population  literacy_rate  unemployment_rate  poverty_rate  ...  \
# 0               9307          69.24              10.24         14.17  ...
# 1             132170          92.14              12.28         38.98  ...
# 2              72727          77.17              12.90         27.20  ...
# 3              43758          90.56               9.06         33.96  ...
# 4              14266          83.92              11.66         16.13  ...
#
#    education_index  slum_population  \
# 0             0.46              183
# 1             0.93            52738
# 2             0.84            29332
# 3             0.51             5953
# 4             0.60             3814
#
#                         employment_type_distribution  \
# 0  {'IT': 33, 'Manufacturing': 22, 'Unskilled Lab...
# 1  {'IT': 26, 'Manufacturing': 17, 'Unskilled Lab...
# 2  {'IT': 20, 'Manufacturing': 17, 'Unskilled Lab...
# 3  {'IT': 25, 'Manufacturing': 37, 'Unskilled Lab...
# 4  {'IT': 20, 'Manufacturing': 34, 'Unskilled Lab...
#
#                            crime_trends_last_5_years  crime_peak_hours  \
# 0  {'2019': 547, '2020': 340, '2021': 1810, '2022...      6 PM - 10 PM
# 1  {'2019': 292, '2020': 758, '2021': 920, '2022'...      10 PM - 2 AM
# 2  {'2019': 2411, '2020': 707, '2021': 1355, '202...      6 PM - 10 PM
# 3  {'2019': 2195, '2020': 2007, '2021': 607, '202...       2 AM - 6 AM
# 4  {'2019': 1193, '2020': 352, '2021': 2901, '202...      10 PM - 2 AM
#
#           seasonal_crime_trends  perceived_safety_index  \
# 0  High during festival seasons                    6.84
# 1        No significant pattern                    5.76
# 2        No significant pattern                    7.99
# 3              Higher in summer                    6.38
# 4        No significant pattern                    6.28
#
#    reported_missing_persons  risk_index  risk_category
# 0                         3       45.66            Low
# 1                         9       91.86           High
# 2                        10       64.31       Moderate
# 3                        28       76.50       Moderate
# 4                        14        4.67            Low
#
# [5 rows x 34 columns]

# %%
police_dataset.shape
# Out:
# (50, 34)

# %%
police_dataset.describe()
# Out:
#         latitude  longitude        pincode     population  male_population  \
# count  50.000000  50.000000      50.000000      50.000000        50.000000
# mean   13.000444  80.251733  600054.040000  272653.520000    136085.960000
# std     0.113992   0.095918      30.011535  141393.459916     70982.236045
# min    12.813343  80.100746  600001.000000   19127.000000      9820.000000
# 25%    12.909996  80.157824  600026.750000  173952.500000     84328.000000
# 50%    12.998880  80.245399  600055.500000  261896.000000    129748.000000
# 75%    13.085865  80.345025  600078.000000  401227.250000    200419.500000
# max    13.197708  80.395099  600099.000000  488761.000000    250093.000000
#
#        female_population  literacy_rate  unemployment_rate  poverty_rate  \
# count          50.000000      50.000000          50.000000     50.000000
# mean       136567.560000      76.885800           8.804200     20.346200
# std         70541.604952      10.464125           3.815591     10.889476
# min          9307.000000      60.440000           2.010000      5.000000
# 25%         89624.500000      68.452500           5.457500      9.602500
# 50%        132148.000000      76.355000           9.775000     20.320000
# 75%        200909.750000      84.505000          11.585000     27.897500
# max        249803.000000      96.600000          14.290000     39.010000
#
#        total_crimes  ...  crime_rate_per_1000  number_of_police_stations  \
# count     50.000000  ...            50.000000                  50.000000
# mean    1488.380000  ...            10.041000                   3.200000
# std      859.298454  ...            14.238656                   1.511858
# min      203.000000  ...             0.580000                   1.000000
# 25%      756.750000  ...             2.817500                   2.000000
# 50%     1445.000000  ...             5.220000                   3.000000
# 75%     2324.000000  ...             9.660000                   5.000000
# max     2995.000000  ...            66.670000                   5.000000
#
#        number_of_cctv_cameras  response_time   avg_income  education_index  \
# count               50.000000      50.000000     50.00000        50.000000
# mean               261.600000      18.904000  27899.88000         0.566800
# std                129.067772       7.531644  12787.90276         0.239902
# min                 14.000000       5.400000   6128.00000         0.200000
# 25%                164.250000      13.315000  16672.25000         0.332500
# 50%                309.000000      19.440000  28501.50000         0.540000
# 75%                363.750000      26.055000  38112.50000         0.795000
# max                467.000000      29.820000  48070.00000         0.990000
#
#        slum_population  perceived_safety_index  reported_missing_persons  \
# count         50.00000                50.00000                 50.000000
# mean       42512.70000                 5.71740                 24.820000
# std        30343.59066                 2.42109                 14.927977
# min           45.00000                 1.41000                  1.000000
# 25%        19278.50000                 3.98000                 14.000000
# 50%        37066.00000                 5.95500                 24.500000
# 75%        65200.25000                 7.67500                 37.000000
# max       117692.00000                 9.94000                 50.000000
#
#        risk_index
# count   50.000000
# mean    50.896400
# std     29.446061
# min      0.440000
# 25%     23.367500
# 50%     54.640000
# 75%     75.032500
# max     99.530000
#
# [8 rows x 27 columns]

# %%
police_dataset.drop(columns=['literacy_rate', 'unemployment_rate','poverty_rate','number_of_police_stations','number_of_cctv_cameras','police_patrolling_frequency','avg_income','education_index','slum_population','employment_type_distribution','seasonal_crime_trends','perceived_safety_index'], inplace=True)

# %%
police_dataset.shape
# Out:
# (50, 22)

# %%
print(police_dataset.columns)
# Out:
# Index(['area_name', 'latitude', 'longitude', 'pincode', 'population',
#        'male_population', 'female_population', 'total_crimes', 'murders',
#        'rapes', 'robberies', 'assaults', 'kidnappings', 'drug_related_crimes',
#        'domestic_violence_cases', 'crime_rate_per_1000', 'response_time',
#        'crime_trends_last_5_years', 'crime_peak_hours',
#        'reported_missing_persons', 'risk_index', 'risk_category'],
#       dtype='object')

# %%
police_dataset["risk_category"] = police_dataset["risk_category"].astype(str)

# %%
print(police_dataset["risk_category"].unique())
# Out:
# ['nan']

# %%
print(police_dataset["risk_category"].value_counts(dropna=False))
# Out:
# risk_category
# Low         22
# Moderate    17
# High        11
# Name: count, dtype: int64

# %%
print(police_dataset["risk_category"])
# Out:
# 0          Low
# 1         High
# 2     Moderate
# 3     Moderate
# 4          Low
# 5         High
# 6     Moderate
# 7     Moderate
# 8          Low
# 9          Low
# 10         Low
# 11    Moderate
# 12         Low
# 13    Moderate
# 14         Low
# 15         Low
# 16    Moderate
# 17         Low
# 18        High
# 19        High
# 20         Low
# 21        High
# 22        High
# 23         Low
# 24    Moderate
# 25    Moderate
# 26         Low
# 27        High
# 28         Low
# 29    Moderate
# 30    Moderate
# 31         Low
# 32         Low
# 33    Moderate
# 34    Moderate
# 35    Moderate
# 36    Moderate
# 37         Low
# 38        High
# 39         Low
# 40        High
# 41        High
# 42         Low
# 43        High
# 44    Moderate
# 45         Low
# 46         Low
# 47         Low
# 48    Moderate
# 49         Low
# Name: risk_category, dtype: object

# %%
# Ensure 'total_crimes' column exists
if "total_crimes" in police_dataset.columns:
    # Define thresholds based on crime counts
    def classify_risk(crime_count):
        if crime_count < 1000:
            return 0  # Low risk
        elif 1000 <= crime_count < 1488:
            return 1  # Medium risk
        else:
            return 2  # High risk

    # Apply function to create risk category
    police_dataset["risk_category"] = police_dataset["total_crimes"].apply(classify_risk)

    print(police_dataset["risk_category"].value_counts())  # Check new distribution
else:
    print("Error: 'total_crimes' column missing")
# Out:
# risk_category
# 2    23
# 0    18
# 1     9
# Name: count, dtype: int64

# %%
police_dataset["risk_category"] = police_dataset["total_crimes"].apply(classify_risk)

# %%
police_dataset['risk_category'].value_counts()
# Out:
# risk_category
# 2    23
# 0    18
# 1     9
# Name: count, dtype: int64

# %%
X = police_dataset[["latitude", "longitude", "total_crimes", "population"]]
Y = police_dataset["risk_category"]

# %%
print(X)
# Out:
#      latitude  longitude  total_crimes  population
# 0   13.130490  80.387909           859       19127
# 1   12.888904  80.378071          1194      262099
# 2   12.946194  80.142256           765      148307
# 3   13.064324  80.371663          2505       86763
# 4   12.896588  80.144548          1533       28431
# 5   12.887408  80.247441           408       39435
# 6   13.062336  80.209633           295      414051
# 7   13.186587  80.255247           823      244088
# 8   12.842917  80.288278          2995      409725
# 9   12.882998  80.133848          1120      475811
# 10  13.004156  80.124485          2204      196404
# 11  12.827852  80.243033          1465      412105
# 12  13.041649  80.169387           203      240628
# 13  13.197708  80.289811          1425      403663
# 14  13.064423  80.346444           947      138987
# 15  13.186536  80.188734          1115      230768
# 16  13.147676  80.155153           696      235410
# 17  12.820950  80.203984          2583      488761
# 18  12.869010  80.390906          1697      434081
# 19  12.999438  80.150691          2535      131434
# 20  13.150724  80.381861           405      176468
# 21  12.860758  80.122045          1679      173114
# 22  12.909835  80.292673          1797      181390
# 23  13.152695  80.322608          2379      270036
# 24  12.935020  80.243357           614      393920
# 25  12.931656  80.297476           507      387919
# 26  13.189242  80.381924          2683      392931
# 27  13.034852  80.359765           905      464699
# 28  13.057130  80.318908          2730       54399
# 29  12.998323  80.226108           637      472450
# 30  12.862161  80.209711          2174      277704
# 31  12.964181  80.228738          2851      431484
# 32  13.126845  80.127699           754      285089
# 33  12.939276  80.378811          1720      157759
# 34  12.915985  80.134891           340       86799
# 35  13.016193  80.113437          2614      261693
# 36  13.026248  80.117204          1863       27943
# 37  13.134508  80.272676          1041      378904
# 38  13.093013  80.332701          2364      129657
# 39  13.157102  80.369194           349      227562
# 40  13.063675  80.193506          1470      240106
# 41  12.873877  80.345713          2424      275478
# 42  12.936999  80.358427          1987      431541
# 43  12.813343  80.298278          1397      481581
# 44  13.063974  80.138971           221      378982
# 45  12.933624  80.165836          1692      197860
# 46  12.965754  80.193827          1055      378606
# 47  12.930458  80.342962          2857      299525
# 48  12.910479  80.395099           685      189595
# 49  13.126149  80.100746          2858      487404

# %%
print(Y)
# Out:
# 0     0
# 1     1
# 2     0
# 3     2
# 4     2
# 5     0
# 6     0
# 7     0
# 8     2
# 9     1
# 10    2
# 11    1
# 12    0
# 13    1
# 14    0
# 15    1
# 16    0
# 17    2
# 18    2
# 19    2
# 20    0
# 21    2
# 22    2
# 23    2
# 24    0
# 25    0
# 26    2
# 27    0
# 28    2
# 29    0
# 30    2
# 31    2
# 32    0
# 33    2
# 34    0
# 35    2
# 36    2
# 37    1
# 38    2
# 39    0
# 40    1
# 41    2
# 42    2
# 43    1
# 44    0
# 45    2
# 46    1
# 47    2
# 48    0
# 49    2
# Name: risk_category, dtype: int64

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (50, 4) (40, 4) (10, 4)

# %% [markdown]
# Training the Model

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
risk_labels = {0: "Low", 1: "Medium", 2: "High"}
y_pred_labels = [risk_labels[p] for p in y_pred]
y_test_labels = [risk_labels[t] for t in Y_test]

# %% [markdown]
# Model Evaluation

# %%
accuracy = accuracy_score(Y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.90

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7866449511400652

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.7727272727272727

# %% [markdown]
# New data for model prediction

# %%
new_data = [[8.7642, 78.1348, 80, 120000]]

# %%
predicted_risk = model.predict(new_data)[0]
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Predicted Crime Risk Level:", risk_labels[predicted_risk])
# Out:
# Predicted Crime Risk Level: Low
